# %%
import numpy as np
from generate_responses import get_results, vectorize_response, plot_response

# %%
results = get_results('results.json')
results_row = results.iloc[57]
v = vectorize_response(results_row)
# Out:
#  E:\Program_Files\Anaconda\envs\testpymc3\lib\site-packages\GPy\kern\src\stationary.py:168: RuntimeWarning:overflow encountered in true_divide
#  E:\Program_Files\Anaconda\envs\testpymc3\lib\site-packages\GPy\kern\src\rbf.py:51: RuntimeWarning:overflow encountered in square
#  E:\Program_Files\Anaconda\envs\testpymc3\lib\site-packages\GPy\kern\src\rbf.py:54: RuntimeWarning:invalid value encountered in multiply

# %%
plot_response(v[:4], figsize=(19,5))
# Out:
#  E:\Projects\Git\Public\Active-Learning\individual_differences\models\new\generate_responses.py:100: RuntimeWarning:invalid value encountered in true_divide

# %%
plot_response(v[:4], figsize=(19,5), plot_entropy='c1')
# Out:
#  E:\Projects\Git\Public\Active-Learning\individual_differences\models\new\generate_responses.py:96: RuntimeWarning:invalid value encountered in true_divide

# %%
plot_response(v[:4], figsize=(19,5), plot_entropy='c2')
# Out:
#  E:\Projects\Git\Public\Active-Learning\individual_differences\models\new\generate_responses.py:92: RuntimeWarning:invalid value encountered in true_divide

# %%
v[:,4,:][1].argmin()
# Out:
# 50
